# %% [markdown]
# <a href="https://colab.research.google.com/github/JesseObed-jesse/Python-Zero-To-Hero-aug/blob/main/Python_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# day 1 of python zero to hero 


# Code:


"""
Python Notes : 


founder of python ​gudio van rossum
in the year of 1991 feb 

* because of google python is famous 
* python was a hobbie project by van rossum
* 

"""

print("Hello coder ")

a = 2
b = 3.5
print(a+b)

print(type(a))
print(type(b))

a = 25;
b = 3.55;
print(a+b);

link_for_colab = 'https://colab.research.google.com/drive/1X6_8i6oqZ1CZujwq13LP7E7sLNxkix6A#scrollTo=MZx_ODWKdrCG&line=1&uniqifier=1'
print(type(a))
print(type(b))
print(type(link))

"""
print statments
triple quotes
f string
string format
define variables
intput
list
if
else
elif
"""
# print statment 
print('Hello coders')
print("Hello coders")
# triple quotes
""" notes """
# f string
a = 15
print(f"Hi i am {a} years old")
# string format
print("hello i am", a, "years old")
print('hello i am', a, 'years old')
# define variables
a = 1
b = 1.2
c = '1.2.3'
print(type(a))
print(type(b))
print(type(c))
# input
inpt = input("Enter a number :")
print(f'Your number is {inpt}')
# list
list1 = [1,2,3,4,5]
list2 = [6,7,8,9,10]
print(list1+list2)

# for loop
for i in list1:
  print(i)


"""Home work of the day 1 

"""

x = int(input("Enter the first digit : "))
y = int(input("Enter the second digit : "))

answer = x ** y
print(f'the power of the numbers {x},{y} is {answer}')
